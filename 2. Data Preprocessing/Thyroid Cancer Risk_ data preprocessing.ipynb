# %%
import pandas as pd
import seaborn as sns

# %%
dataset=pd.read_csv("thyroid_cancer_risk_data.csv")

# %%
dataset
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %%
dataset.drop(['Patient_ID', 'Ethnicity'], axis=1, inplace=True)
dataset
# Out:
#         Age  Gender  Country Family_History Radiation_Exposure  \
# 0        66    Male   Russia             No                Yes
# 1        29    Male  Germany             No                Yes
# 2        86    Male  Nigeria             No                 No
# 3        75  Female    India             No                 No
# 4        35  Female  Germany            Yes                Yes
# ...     ...     ...      ...            ...                ...
# 212686   58  Female    India             No                 No
# 212687   89    Male    Japan             No                 No
# 212688   72  Female  Nigeria             No                 No
# 212689   85  Female   Brazil             No                 No
# 212690   46  Female    Japan             No                 No
#
#        Iodine_Deficiency Smoking Obesity Diabetes  TSH_Level  T3_Level  \
# 0                     No      No      No       No       9.37      1.67
# ...

# %% [markdown]
# # Data PreProcessing

# %% [markdown]
# # 1.Checking for Null Values

# %%
# First we need to check do we have any null values in the dataset
dataset.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Country                0
# Family_History         0
# Radiation_Exposure     0
# Iodine_Deficiency      0
# Smoking                0
# Obesity                0
# Diabetes               0
# TSH_Level              0
# T3_Level               0
# T4_Level               0
# Nodule_Size            0
# Thyroid_Cancer_Risk    0
# Diagnosis              0
# dtype: int64

# %% [markdown]
# # ---> No Null values in the Dataset

# %%
dataset.to_csv("preprocessed_thyroid_data.csv", index=False)
